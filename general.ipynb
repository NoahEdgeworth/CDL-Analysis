# %%
import pandas as pd

# %%
overall_player_df = pd.read_csv('Player Stats/Player Stats MW3_Overall Player Stats_Table.csv')
overall_player_df
# Out:
#          Player          Team   K/D  Team Adj K/D % of Teams Kills  \
# 0       Slasher        Breach  1.24          1.25           26.82%
# 1       Cellium          Faze  1.30          1.16           24.34%
# 2          Pred         Optic  1.17          1.11           27.38%
# 3        Attach        Legion  1.06          1.11           26.37%
# 4          Lynz         Rokkr  1.04          1.11           27.07%
# 5         Gwinn  Royal Ravens  1.02          1.10           26.69%
# 6         iLLeY         Surge  1.04          1.09           26.63%
# 7          Skyz     Subliners  1.12          1.08           23.78%
# 8         Scrap         Ultra  1.17          1.07           27.12%
# 9         HyDra     Subliners  1.10          1.07           27.11%
# 10   Diamondcon    Guerrillas  1.05          1.06           26.41%
# 11       Ghosty       Thieves  0.98          1.06           25.47%
# 12      MettalZ      Heretics  1.06          1.06           26.81%
# ...

# %%
filtered_table_overall_player = overall_player_df[['Player', 'Team', 'K/D', '% of Teams Kills', '% of Teams Deaths']]
filtered_table_overall_player.sort_values('K/D',ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 1       Cellium          Faze  1.30           24.34%            21.02%
# 0       Slasher        Breach  1.24           26.82%            21.48%
# 8         Scrap         Ultra  1.17           27.12%            25.45%
# 2          Pred         Optic  1.17           27.38%            24.57%
# 14         Simp          Faze  1.16           26.84%            26.03%
# 7          Skyz     Subliners  1.12           23.78%            22.03%
# 9         HyDra     Subliners  1.10           27.11%            25.45%
# 25       CleanX         Ultra  1.10           26.29%            26.41%
# 29      Insight         Ultra  1.09           22.53%             22.7%
# 37       Drazah          Faze  1.08           24.51%            25.62%
# 3        Attach        Legion  1.06           26.37%            23.76%
# 12      MettalZ      Heretics  1.06           26.81%            25.27%
# ...

# %% [markdown]
# Overall K/D Leaders for Major 1 - Cellium, Slasher, Scrap, Pred, Simp

# %%
hp_player_df = pd.read_csv('Player Stats/Player Stats MW3_Hardpoint Player Stats_Table.csv')
hp_player_df
# Out:
#          Player          Team  Impact   K/D  Team Adj K/D   KP10  NTK Per 10  \
# 0         Scrap         Ultra   26.44  1.20          1.08  25.40       18.58
# 1        CleanX         Ultra   21.93  1.13          1.01  23.45       16.82
# 2       Insight         Ultra   19.84  1.15          1.03  20.65       15.59
# 3       Slasher        Breach   15.84  1.38          1.30  22.38       17.62
# 4         Envoy         Ultra   14.54  1.00          0.89  20.91       14.68
# 5          Pred         Optic   11.12  1.14          1.08  23.22       16.65
# 6         Kenny         Optic    9.23  1.10          1.04  23.01       16.28
# 7        TJHaLy  Royal Ravens    8.09  1.01          0.96  20.77       15.41
# 8          Simp          Faze    6.88  1.19          1.12  22.88       16.27
# 9         Hydra     Subliners    6.79  1.10          1.11  22.17       16.12
# 10        Dashy         Optic    6.72  1.07          1.02  19.43       15.48
# ...

# %%
filtered_table_hp_player = hp_player_df[['Player', 'Team', 'K/D', '% of Teams Kills', '% of Teams Deaths']]
filtered_table_hp_player.sort_values('K/D', ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 3       Slasher        Breach  1.38           26.93%            20.67%
# 0         Scrap         Ultra  1.20           28.09%            26.13%
# 8          Simp          Faze  1.19           27.83%             24.8%
# 16      Cellium          Faze  1.15           23.66%            21.91%
# 2       Insight         Ultra  1.15           22.84%            22.27%
# 5          Pred         Optic  1.14           27.29%             25.3%
# 19        HyDra     Subliners  1.13            27.6%            25.27%
# 1        CleanX         Ultra  1.13           25.93%            25.64%
# 23   Diamondcon    Guerrillas  1.10           26.65%            24.34%
# 6         Kenny         Optic  1.10           27.04%            25.96%
# 9         Hydra     Subliners  1.10           27.85%            25.16%
# 22         Skyz     Subliners  1.09           24.07%            22.83%
# ...

# %% [markdown]
# Top K/D Leaders for HP Major 1 - Slasher, Scrap, Simp, Cellium, Insight

# %%
snd_player_df = pd.read_csv('Player Stats/Player Stats MW3_SND Player Stats_Table.csv')
snd_player_df
# Out:
#          Player          Team  Impact Rating   K/D  Team Adj K/D  \
# 0       Cellium          Faze           0.88  1.76          1.35
# 1          Simp          Faze           0.72  1.27          0.97
# 2       Insight         Ultra           0.69  1.43          1.18
# 3        CleanX         Ultra           0.68  1.38          1.14
# 4         aBeZy          Faze           0.65  1.22          0.93
# 5        Abuzah         Surge           0.51  1.27          1.19
# 6         iLLeY         Surge           0.48  1.22          1.14
# 7         Scrap         Ultra           0.48  1.13          0.93
# 8        Drazah          Faze           0.45  1.10          0.84
# 9          Skyz     Subliners           0.30  1.20          1.15
# 10        Envoy         Ultra           0.26  0.96          0.79
# 11       Attach        Legion           0.24  1.30          1.34
# 12       KiSMET     Subliners           0.22  1.09          1.04
# ...

# %%
filtered_table_snd_player = snd_player_df[['Player', 'Team', 'K/D', '% of Teams Kills', '% of Teams Deaths']]
filtered_table_snd_player.sort_values('K/D', ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 0       Cellium          Faze  1.76           24.93%            18.41%
# 2       Insight         Ultra  1.43           26.47%            22.45%
# 3        CleanX         Ultra  1.38           27.31%            23.98%
# 11       Attach        Legion  1.30           27.56%            20.56%
# 5        Abuzah         Surge  1.27           27.69%            23.28%
# 1          Simp          Faze  1.27           27.42%            28.16%
# 4         aBeZy          Faze  1.22           26.32%            28.16%
# 6         iLLeY         Surge  1.22           27.96%            24.43%
# 9          Skyz     Subliners  1.20           24.37%            21.26%
# 14         Lynz         Rokkr  1.18           30.12%            24.23%
# 17         Pred         Optic  1.18           28.01%            24.33%
# 7         Scrap         Ultra  1.13           25.63%            27.55%
# ...

# %% [markdown]
# SnD K/D Leaders for Major 1 - Callium, Insight, CleanX, Attach, Abuzah

# %%
control_player_df = pd.read_csv('Player Stats/Player Stats MW3_Control Player Stats_Table.csv')
control_player_df
# Out:
#          Player          Team  Impact Rating   K/D  Team Adj K/D  \
# 0       Slasher        Breach           0.53  1.18          1.14
# 1   JoeDeceives       Thieves           0.28  1.11          1.12
# 2       Cellium          Faze           0.27  1.45          1.24
# 3         Envoy         Ultra           0.24  1.13          1.08
# 4         Scrap         Ultra           0.24  1.14          1.08
# 5          Pred         Optic           0.24  1.22          1.16
# 6          Afro       Thieves           0.22  0.99          1.00
# 7         Lucky      Heretics           0.21  1.13          1.11
# 8       MettalZ      Heretics           0.21  1.09          1.07
# 9        Drazah          Faze           0.20  1.22          1.04
# 10        Vikul      Heretics           0.19  1.08          1.06
# 11       CleanX         Ultra           0.19  0.99          0.95
# 12        Cammy       Thieves           0.19  0.92          0.93
# ...

# %%
filtered_table_control_player = control_player_df[['Player', 'Team', 'K/D', '% of Teams Kills', '% of Teams Deaths']]
filtered_table_control_player.sort_values('K/D', ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 2       Cellium          Faze  1.45            25.2%            20.34%
# 5          Pred         Optic  1.22           27.27%            23.56%
# 9        Drazah          Faze  1.22           25.39%            24.48%
# 0       Slasher        Breach  1.18           24.77%            21.63%
# 4         Scrap         Ultra  1.14              26%            23.98%
# 25         Skyz     Subliners  1.14           23.16%            21.18%
# 3         Envoy         Ultra  1.13           26.45%            24.56%
# 7         Lucky      Heretics  1.13            25.6%            23.11%
# 1   JoeDeceives       Thieves  1.11           27.13%            24.23%
# 35        Gwinn  Royal Ravens  1.10           28.61%            23.23%
# 8       MettalZ      Heretics  1.09           27.03%            25.31%
# 23        HyDra     Subliners  1.09           26.86%            25.74%
# ...

# %% [markdown]
# Control K/D Leaders for Major 1 - Cellium, Pred, Drazah, Slasher, Scrap

# %%
filtered_table_overall_player.sort_values('% of Teams Kills', ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 2          Pred         Optic  1.17           27.38%            24.57%
# 8         Scrap         Ultra  1.17           27.12%            25.45%
# 9         HyDra     Subliners  1.10           27.11%            25.45%
# 4          Lynz         Rokkr  1.04           27.07%            24.43%
# 14         Simp          Faze  1.16           26.84%            26.03%
# 0       Slasher        Breach  1.24           26.82%            21.48%
# 12      MettalZ      Heretics  1.06           26.81%            25.27%
# 19       Snoopy        Breach  0.99           26.72%            26.47%
# 5         Gwinn  Royal Ravens  1.02           26.69%            24.36%
# 6         iLLeY         Surge  1.04           26.63%            24.51%
# 27        Vivid         Rokkr  0.93           26.55%            26.68%
# 10   Diamondcon    Guerrillas  1.05           26.41%            24.83%
# ...

# %% [markdown]
# Players with the Highest % of Teams Overall Kills - Pred, Scrap, Hydra, Lynz, and Simp

# %%
filtered_table_overall_player.sort_values('% of Teams Deaths', ascending=False)
# Out:
#          Player          Team   K/D % of Teams Kills % of Teams Deaths
# 49        aBeZy          Faze  1.00           24.31%            27.32%
# 47       JurNii      Heretics  0.90           24.24%            26.85%
# 48       KiSMET     Subliners  0.92           23.82%            26.73%
# 27        Vivid         Rokkr  0.93           26.55%            26.68%
# 19       Snoopy        Breach  0.99           26.72%            26.47%
# 36      Estreal    Guerrillas  0.95           25.34%            26.44%
# 25       CleanX         Ultra  1.10           26.29%            26.41%
# 46      Shotzzy         Optic  0.97           24.23%            26.35%
# 33        Kenny         Optic  1.02           25.62%            26.35%
# 31     Capsidal        Breach  0.97            25.9%            26.33%
# 35         Huke         Surge  0.92            25.3%            26.22%
# 14         Simp          Faze  1.16           26.84%            26.03%
# ...

# %% [markdown]
# Players with Highest % of Teams Overall Deaths - Abezy, Jurnii, Kismet, Vivid, Snoopy
